# %%
pip install altair vega_datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 21.2.1 is available.
# You should consider upgrading via the 'C:\Users\Adminuser\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install --user --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.9.exe and pip3.exe are installed in 'C:\Users\Adminuser\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.1.3; however, version 21.2.1 is available.
# You should consider upgrading via the 'C:\Users\Adminuser\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install altair vega_datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import altair as alt
import pandas as pd
#Select a dataset
data = pd.read_csv("gar_data.csv")
#create a data dashboard using Altair
#Let’s start by looking at the average number of workers per department 
alt.Chart(data).mark_bar().encode(
    y='department',
    x='average(no_of_workers)'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# The Sewing department on average has the highest number of employees.

# %%
import altair as alt
import pandas as pd
#Select a dataset
data = pd.read_csv("gar_data.csv")
#create a data dashboard using Altair
#Let’s start by looking at the average number of workers per department 
alt.Chart(data).mark_bar().encode(
    y='actual_productivity',
    x='quarter'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Productivity is highes in Quarter 3.

# %%
alt.Chart(data).mark_line().encode(
   x="month(date):O",
   y="actual_productivity",
   color="targeted_productivity",
)
# Out:
# alt.Chart(...)

# %%
# distribution of workers over time
import altair as alt
import pandas as pd
data = pd.read_csv("gar_data.csv")
alt.Chart(data).mark_tick().encode(
    x='actual_productivity',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# #the data shows productivity is skwed towards 1.0

# %%
#compare target productivity with actual

import altair as alt
import pandas as pd
data = pd.read_csv("gar_data.csv")

base = alt.Chart(data).encode(x='month(date):O')
bar = base.mark_bar().encode(y='actual_productivity:Q')

line =  base.mark_line(color='red').encode(
    y='targeted_productivity:Q'
)
(bar + line).properties(width=600)
# Out:
# alt.LayerChart(...)

# %%
import altair as alt
import pandas as pd
data = pd.read_csv("gar_data.csv")
alt.Chart(data).mark_bar().encode(
    x='month(date):N',
    y='count()',
    color='department',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# The chart above shows the involvement of each deparmtent in production each month

# %%
#to determine the pattern for productivity to explore the relationship between departmetnt, overtime, no of workers and actual productivity
import altair as alt
import pandas as pd
data = pd.read_csv("gar_data.csv")
alt.Chart(data).mark_area(opacity=0.3).encode(
    x="quarter:O",
    y=alt.Y("actual_productivity:Q", stack=None),
    color="department:N"
).properties(height=250, width=900)
# Out:
# alt.Chart(...)

# %% [markdown]
# The layered histogram shows the productivity of departments across the three months. As expected fininshing is more productive in the final stage of production.  it also indicates the finishing departmetnt

# %%
#to determine the pattern for productivity to explore the relationship between departmetnt, overtime, no of workers and actual productivity
import altair as alt
import pandas as pd
data = pd.read_csv("gar_data.csv")
alt.Chart(data).properties(width=550)

base =line = base.mark_line().encode(
    x='month(date):O',
    y='no_of_workers',
    color='average(actual_productivity)'
)

rule = base.mark_rule().encode(
    y='average(targeted_productivity)',
    color='department',
    size=alt.value(2)
)

line + rule
# Out:
# alt.LayerChart(...)
